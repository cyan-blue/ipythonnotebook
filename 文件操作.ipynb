# %%
import os
import re
dir="/home/bowhead/gululu/gululu/var/log"
pt = re.compile('^user-(\d+)[-(\w+)]+.app.log$')
for root,dirs,files in os.walk(dir):
    for file in files:
        tt = pt.findall(file)
        print tt, file
#         print tt
#         print file
     
#         print os.path.join(root,file)
# Out:
# ['2140'] user-2140-1fa7a838-6acf-313d-9d54-55480acdd8a9.app.log
# ['7762'] user-7762-D3DA340A-EFA4-4580-829F-8E0C54AB0D44.app.log
# [] ut_1234-158e26a7c43.update
# ['7312'] user-7312-ef4e7a2c-103c-3831-832f-4f3e469d1351.app.log
# ['7867'] user-7867-D16992E2-207A-4817-ACA3-F33F84BE57F5.app.log
# [] 2007-158f2074ce5.update
# ['6940'] user-6940-7A2C2FFB-F940-414A-892C-7748617A2026.app.log
# ['1068'] user-1068-ae42b277-c5de-3276-acc6-dd3916bc5a73.app.log
# [] 2070-158b9b18950.abc
# ['8683'] user-8683-8FE51D20-5A3F-4C1C-A3F6-D0EDEDF10F54.app.log
# ['4417'] user-4417-14a6b904-2298-351e-bf84-f9095e81b88c.app.log
# ['7549'] user-7549-c538ed6f-a158-3699-b3ee-56c82ac406f9.app.log
# ['8203'] user-8203-CE4DE728-41AC-45A7-927A-C913EE5A0282.app.log
# ['7936'] user-7936-0451C380-0B2E-4BD8-8CF9-8C4F044EEEE7.app.log
# [] ut_1235-158dc60eadd.update
# ['6526'] user-6526-FD8CF6E2-0EA1-4362-9704-9D846AF1FA70.app.log
# [] 2007-1581a7934b1.update
# [] e2e_589f24b791@ut.bd_6_0.rt.log
# ...

# %%
import re
a = "use1r-2140-1fa7a838-6acf-313d-9d54-55480acdd8a9.app.log"
pt = re.compile('^user-(\d+)[-(\w+)]+.app.log$')
tt = pt.findall(a)
print tt
if len(tt) > 0:
    print "qqqq"
# Out:
# []

# %%
os.getcwd()
# Out:
# '/home/bowhead/gululu/workplace/ipythonnotebook'
